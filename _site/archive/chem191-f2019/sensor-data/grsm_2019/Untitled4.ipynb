% %%
[dat,tim,n1,n2,n3,n4,n5] = textread('20191011_EBAM.TXT', "%s %s %f %f %f %f %f");
# dat = importdata('20191011_EBAM.TXT', '\t');

% %%
dat
% Out:
% dat =
% {
%   [1,1] = EBAM
%   [2,1] = 6.00
%   [3,1] = 4.72
%   [4,1] = 851.09
%   [5,1] = 60.65
%   [6,1] = 21.43
%   [7,1] = 13:18:08
%   [8,1] = 2019-10-11
%   [9,1] = EBAM
%   [10,1] = 3.00
%   [11,1] = 17.27
%   [12,1] = 850.93
%   [13,1] = 65.62
%   [14,1] = 18.12
%   [15,1] = 14:31:24
%   [16,1] = 2019-10-11
%   [17,1] = EBAM
%   [18,1] = 3.40
%   [19,1] = 23.56
%   [20,1] = 850.82
%   [21,1] = 74.31
%   [22,1] = 15.78
%   [23,1] = 15:44:40
%   [24,1] = 2019-10-11
%   [25,1] = EBAM
%   [26,1] = 3.00
%   [27,1] = 28.01
%   [28,1] = 850.86
%   [29,1] = 83.93
%   [30,1] = 13.72
%   [31,1] = 16:57:56
%   [32,1] = 2019-10-11
%   [33,1] = EBAM
%   [34,1] = 3.00
%   [35,1] = 33.15
%   [36,1] = 851.05
%   [37,1] = 90.57
%   [38,1] = 12.09
%   [39,1] = 18:11:12
%   [40,1] = 2019-10-11
%   [41,1] = EBAM
%   [42,1] = 4.00
%   [43,1] = 36.05
%   [44,1] = 851.29
%   [45,1] = 90.87
%   [46,1] = 11.94
%   [47,1] = 19:24:28
%   [48,1] = 2019-10-11
%   [49,1] = EBAM
%   [50,1] = 6.00
% ...
